# %%
from tools import *
# Out:
# devices: PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')

# %%
prepare_dirs(task='training')
# Out:
# Downloading FD001.zip from Google Drive...
# Downloading...
# From (original): https://drive.google.com/uc?id=1TnV9sAX2My-R3iSGamX3rVAezoBsGY_M
# From (redirected): https://drive.google.com/uc?id=1TnV9sAX2My-R3iSGamX3rVAezoBsGY_M&confirm=t&uuid=5a094b01-8958-475e-a363-d80c21067834
# To: D:\virtualenv\src\thesis\cmapss\training\lstm\input\CMAPSSData\FD001.zip
# 100%|█████████████████████████████████████████████████████████████████████████████| 29.5M/29.5M [00:03<00:00, 8.09MB/s]
# Extracting FD001.zip...
# Extraction complete: ./input\CMAPSSData
# Input directory
# './input'
# URL input dataset
# 'https://drive.google.com/file/d/1LU1DQuv7_CzBy2_Abgjg3HsvNDme361O/view?usp=drive_link'
# Input dataset directory
# './input\\CMAPSSData'
# Output directory
# './working'
# Output models directory
# './working\\models'
# Output plots directory
# './working\\plots'

# %%
data_ftype = '.npy'

ts_train_features_name = 'ts_train_features' + data_ftype
ts_train_features_path = os.path.join(dataset_dir, ts_train_features_name)
ts_train_targets_name = 'ts_train_targets' + data_ftype
ts_train_targets_path = os.path.join(dataset_dir, ts_train_targets_name)

ts_val_features_name = 'ts_val_features' + data_ftype
ts_val_features_path = os.path.join(dataset_dir, ts_val_features_name)
ts_val_targets_name = 'ts_val_targets' + data_ftype
ts_val_targets_path = os.path.join(dataset_dir, ts_val_targets_name)

ts_test_features_name = 'ts_test_features' + data_ftype
ts_test_features_path = os.path.join(dataset_dir, ts_test_features_name)
ts_test_targets_name = 'ts_test_targets' + data_ftype
ts_test_targets_path = os.path.join(dataset_dir, ts_test_targets_name)

ts_train_features = np.load(ts_train_features_path)
ts_train_targets = np.load(ts_train_targets_path)

ts_val_features = np.load(ts_val_features_path)
ts_val_targets = np.load(ts_val_targets_path)

ts_test_features = np.load(ts_test_features_path)
ts_test_targets = np.load(ts_test_targets_path)

# %%
nprint("Training features shape", ts_train_features.shape)
nprint("Training targets shape", ts_train_targets.shape)
nprint("Validation features shape", ts_val_features.shape)
nprint("Validation targets shape", ts_val_targets.shape)
nprint("Testing features shape", ts_test_features.shape)
nprint("Testing targets shape", ts_test_targets.shape)
# Out:
# Training features shape
# (14184, 30, 14)
# Training targets shape
# (14184,)
# Validation features shape
# (3547, 30, 14)
# Validation targets shape
# (3547,)
# Testing features shape
# (497, 30, 14)
# Testing targets shape
# (100,)

# %%
plot_lrdecay()

# %%
model = RULEstimator.get_model(
    dataset_name=dataset_name,
    window_length=window_length,
    num_features=ts_train_features.shape[2],
    num_targets=1 if len(ts_train_targets.shape)==1 else ts_train_targets.shape[1],
    loss=loss(),
    optimizer=optimizer()
).build()
model.summary()


start_time = time.time()
nprint('Training started: ', time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()))
history = model.fit(
    ts_train_features, 
    ts_train_targets, 
    epochs=epochs,
    validation_data=(
        ts_val_features, 
        ts_val_targets
    ),
    callbacks=callbacks(
        scheduler=scheduler, 
        verbose=verbose, 
        stopping_metric='val_loss', 
        patience=int((20*epochs)/100)
    ),
    batch_size=batch_size, 
    verbose=verbose
)
nprint('Training ended: ', time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()))
end_time = time.time()
training_duration = end_time - start_time
nprint('Training duration', '{:.2f} seconds'.format(training_duration))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 128)             │          73,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 30, 64)              │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 96)                  │           3,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 150,753 (588.88 KB)
#  Trainable params: 150,753 (588.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Training started:
# '2024-11-28 15:51:41'
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 5997.5083 - val_loss: 365.1749 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 293.3908 - val_loss: 220.7815 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - loss: 216.4857 - val_loss: 197.5427 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.001.
# Epoch 4/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 208.8293 - val_loss: 179.2860 - learning_rate: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.001.
# Epoch 5/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 191.3378 - val_loss: 198.1180 - learning_rate: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.001.
# Epoch 6/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 182.3232 - val_loss: 186.0322 - learning_rate: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.001.
# Epoch 7/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 179.4958 - val_loss: 188.6947 - learning_rate: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.001.
# Epoch 8/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 178.9791 - val_loss: 212.1243 - learning_rate: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.001.
# Epoch 9/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - loss: 181.8473 - val_loss: 184.4461 - learning_rate: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.001.
# Epoch 10/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 172.9681 - val_loss: 163.3771 - learning_rate: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 11/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 150.5030 - val_loss: 149.8143 - learning_rate: 1.0000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 12/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 145.0677 - val_loss: 145.0386 - learning_rate: 1.0000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 13/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 148.3143 - val_loss: 144.2753 - learning_rate: 1.0000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 14/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - loss: 145.4785 - val_loss: 149.7204 - learning_rate: 1.0000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 15/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - loss: 149.8915 - val_loss: 142.9121 - learning_rate: 1.0000e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 16/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 145.4819 - val_loss: 141.3698 - learning_rate: 1.0000e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 17/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 140.9993 - val_loss: 143.2786 - learning_rate: 1.0000e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 18/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 143.8787 - val_loss: 140.5814 - learning_rate: 1.0000e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 19/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 138.8975 - val_loss: 140.1065 - learning_rate: 1.0000e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 20/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 138.5423 - val_loss: 139.5314 - learning_rate: 1.0000e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 21/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 138.2458 - val_loss: 139.1907 - learning_rate: 1.0000e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 22/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 140.9078 - val_loss: 141.1398 - learning_rate: 1.0000e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 23/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 141.0275 - val_loss: 136.4821 - learning_rate: 1.0000e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 24/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 137.4977 - val_loss: 138.9020 - learning_rate: 1.0000e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 25/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 141.2402 - val_loss: 141.6552 - learning_rate: 1.0000e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 26/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 15s 132ms/step - loss: 139.1076 - val_loss: 142.8055 - learning_rate: 1.0000e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 27/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 135.2504 - val_loss: 137.0815 - learning_rate: 1.0000e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 28/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 132.9990 - val_loss: 133.6895 - learning_rate: 1.0000e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 29/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 132.3541 - val_loss: 133.0422 - learning_rate: 1.0000e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 30/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 128ms/step - loss: 134.4159 - val_loss: 132.0004 - learning_rate: 1.0000e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 31/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 127ms/step - loss: 132.1823 - val_loss: 129.6054 - learning_rate: 1.0000e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 32/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 127.8158 - val_loss: 128.7090 - learning_rate: 1.0000e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 33/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 124.6518 - val_loss: 127.5346 - learning_rate: 1.0000e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 34/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 125.7438 - val_loss: 124.9812 - learning_rate: 1.0000e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 35/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 114ms/step - loss: 123.5999 - val_loss: 126.1687 - learning_rate: 1.0000e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 36/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - loss: 121.5709 - val_loss: 125.8687 - learning_rate: 1.0000e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 37/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 123.2344 - val_loss: 121.4902 - learning_rate: 1.0000e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 38/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - loss: 119.0284 - val_loss: 130.7754 - learning_rate: 1.0000e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 39/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 126.7910 - val_loss: 120.4390 - learning_rate: 1.0000e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 40/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 116.1889 - val_loss: 119.6211 - learning_rate: 1.0000e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 41/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 117.1737 - val_loss: 117.4449 - learning_rate: 1.0000e-05
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 42/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 108.2534 - val_loss: 116.9602 - learning_rate: 1.0000e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 43/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 111.8294 - val_loss: 115.9929 - learning_rate: 1.0000e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 44/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 110.2471 - val_loss: 117.2346 - learning_rate: 1.0000e-05
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 45/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 111.4583 - val_loss: 115.9619 - learning_rate: 1.0000e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 46/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - loss: 110.3031 - val_loss: 116.8229 - learning_rate: 1.0000e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 47/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 110.9705 - val_loss: 116.6817 - learning_rate: 1.0000e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 48/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 110.5439 - val_loss: 115.9558 - learning_rate: 1.0000e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 49/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 108.2261 - val_loss: 115.6757 - learning_rate: 1.0000e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 50/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 108.3008 - val_loss: 115.6308 - learning_rate: 1.0000e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 51/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 108.7173 - val_loss: 115.2112 - learning_rate: 1.0000e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 52/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 105.1992 - val_loss: 114.5147 - learning_rate: 1.0000e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 53/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 108.9975 - val_loss: 114.0311 - learning_rate: 1.0000e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 54/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 109.8347 - val_loss: 114.4576 - learning_rate: 1.0000e-05
#
# Epoch 55: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 55/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 108.2317 - val_loss: 114.9817 - learning_rate: 1.0000e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 56/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 113ms/step - loss: 108.4899 - val_loss: 114.3814 - learning_rate: 1.0000e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 57/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 104.1838 - val_loss: 114.0169 - learning_rate: 1.0000e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 58/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 114ms/step - loss: 108.3708 - val_loss: 113.6405 - learning_rate: 1.0000e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 59/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 108.0556 - val_loss: 113.2025 - learning_rate: 1.0000e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 60/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 107.6835 - val_loss: 113.9421 - learning_rate: 1.0000e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 61/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 109.4443 - val_loss: 113.5289 - learning_rate: 1.0000e-05
#
# Epoch 62: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 62/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 117ms/step - loss: 107.0086 - val_loss: 112.8346 - learning_rate: 1.0000e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 63/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - loss: 107.8427 - val_loss: 113.9727 - learning_rate: 1.0000e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 64/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 107.0005 - val_loss: 112.5675 - learning_rate: 1.0000e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 65/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 102.0967 - val_loss: 112.5182 - learning_rate: 1.0000e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 66/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 104.7704 - val_loss: 112.4263 - learning_rate: 1.0000e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 67/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 107.2861 - val_loss: 113.3304 - learning_rate: 1.0000e-05
#
# Epoch 68: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 68/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 108.4561 - val_loss: 112.3786 - learning_rate: 1.0000e-05
#
# Epoch 69: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 69/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 105.1379 - val_loss: 112.6454 - learning_rate: 1.0000e-05
#
# Epoch 70: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 70/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 106.4266 - val_loss: 112.4999 - learning_rate: 1.0000e-05
#
# Epoch 71: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 71/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 106.3440 - val_loss: 111.5324 - learning_rate: 1.0000e-05
#
# Epoch 72: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 72/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 103.8234 - val_loss: 112.3844 - learning_rate: 1.0000e-05
#
# Epoch 73: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 73/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 105.2592 - val_loss: 110.7156 - learning_rate: 1.0000e-05
#
# Epoch 74: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 74/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - loss: 103.1461 - val_loss: 110.8157 - learning_rate: 1.0000e-05
#
# Epoch 75: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 75/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 116ms/step - loss: 106.1738 - val_loss: 111.3007 - learning_rate: 1.0000e-05
#
# Epoch 76: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 76/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 104.6201 - val_loss: 110.8544 - learning_rate: 1.0000e-05
#
# Epoch 77: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 77/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 103.0797 - val_loss: 110.8298 - learning_rate: 1.0000e-05
#
# Epoch 78: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 78/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 104.3346 - val_loss: 111.1678 - learning_rate: 1.0000e-05
#
# Epoch 79: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 79/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 19s 88ms/step - loss: 105.7845 - val_loss: 110.3462 - learning_rate: 1.0000e-05
#
# Epoch 80: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 80/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 101.5553 - val_loss: 110.1649 - learning_rate: 1.0000e-05
#
# Epoch 81: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 81/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 116ms/step - loss: 103.1368 - val_loss: 110.8033 - learning_rate: 1.0000e-05
#
# Epoch 82: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 82/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 102.4767 - val_loss: 109.7220 - learning_rate: 1.0000e-05
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 83/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - loss: 101.7628 - val_loss: 110.5267 - learning_rate: 1.0000e-05
#
# Epoch 84: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 84/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 102.8691 - val_loss: 109.3665 - learning_rate: 1.0000e-05
#
# Epoch 85: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 85/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 102.3479 - val_loss: 109.8647 - learning_rate: 1.0000e-05
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 86/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 103.6969 - val_loss: 109.7132 - learning_rate: 1.0000e-05
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 87/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 102.2733 - val_loss: 108.9745 - learning_rate: 1.0000e-05
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 88/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 101.2525 - val_loss: 109.0086 - learning_rate: 1.0000e-05
#
# Epoch 89: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 89/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 102.6881 - val_loss: 108.4457 - learning_rate: 1.0000e-05
#
# Epoch 90: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 90/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - loss: 100.8975 - val_loss: 108.5632 - learning_rate: 1.0000e-05
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 91/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - loss: 100.6676 - val_loss: 108.8337 - learning_rate: 1.0000e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 92/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - loss: 102.0633 - val_loss: 107.9996 - learning_rate: 1.0000e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 93/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - loss: 101.6099 - val_loss: 107.5912 - learning_rate: 1.0000e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 94/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 103.1971 - val_loss: 109.6065 - learning_rate: 1.0000e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 95/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 100.7231 - val_loss: 107.5139 - learning_rate: 1.0000e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 96/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - loss: 98.7994 - val_loss: 107.4708 - learning_rate: 1.0000e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 97/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 97.8266 - val_loss: 107.4824 - learning_rate: 1.0000e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 98/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 100.5000 - val_loss: 107.8335 - learning_rate: 1.0000e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 99/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - loss: 98.5810 - val_loss: 107.5130 - learning_rate: 1.0000e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.0000000000000003e-05.
# Epoch 100/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 95.4566 - val_loss: 106.9696 - learning_rate: 1.0000e-05
# Training ended:
# '2024-11-28 16:12:35'
# Training duration
# '1253.93 seconds'

# %%
modeltype = 'LSTM'

lstm_model_name = '{}_{}'.format(dataset_name, modeltype)
lstm_model_files_dir = os.path.join(out_models_dir, lstm_model_name)
os.makedirs(lstm_model_files_dir)

# %%
ftype = 'keras'
lstm_model_file_name = '{}.{}'.format(lstm_model_name, ftype)
lstm_model_path = os.path.join(lstm_model_files_dir, lstm_model_file_name)
model.save(filepath=lstm_model_path)
nprint('LSTM model path', lstm_model_path)
# Out:
# LSTM model path
# './working\\models\\FD001_LSTM\\FD001_LSTM.keras'

# %%
ftype = 'json'
lstm_model_history_name = '{}_{}_{}.{}'.format(dataset_name, modeltype, 'history', ftype) 
lstm_model_history_path = os.path.join(lstm_model_files_dir, lstm_model_history_name)
with open(lstm_model_history_path, "w") as file: 
    json.dump({'history': history.history}, file, indent=4)
nprint('LSTM model history path', lstm_model_history_path)
display_training_performance(history)
# Out:
# LSTM model history path
# './working\\models\\FD001_LSTM\\FD001_LSTM_history.json'
#       loss   val_loss  learning_rate  epoch
# 100.408684 107.470787        0.00001     95
# 100.124794 107.482407        0.00001     96
# 100.183159 107.833504        0.00001     97
#  99.892738 107.513016        0.00001     98
#  99.721687 106.969620        0.00001     99

# %%
ftype = 'zip'
shutil.make_archive(lstm_model_files_dir, ftype, lstm_model_files_dir)
shutil.rmtree(lstm_model_files_dir)
